# %% [markdown]
# # MULTIMODAL PHISHING DETECTION NOTEBOOK

# %% [markdown]
# # Explainable and Efficient Multi-Modal Phishing Detection
#
# ## A Hybrid Approach Integrating Image Analysis and NLP-Based Text Classification
#
# ### Project Overview
#
# This project implements a **multimodal phishing detection system** that combines visual (website screenshots) and textual (HTML metadata) features to classify websites as phishing or benign. The system employs a hybrid deep learning architecture integrating MobileNetV2 for visual feature extraction and XLM-RoBERTa for textual feature extraction, fused through an attention mechanism before binary classification.

# %% [markdown]
# # Dataset Setup
#
# ## Step 1: Add Dataset Links to Google Drive
#
# **Important:** Before running this notebook, you need to add the dataset zip files to your Google Drive. You have two options:
#
# ### Option A: Add Shortcuts to Google Drive (Recommended for Large Files)
#
# Since the datasets are very large (~7.3GB for phishing, ~56GB for benign), instead of downloading and re-uploading, you can add shortcuts to your Google Drive:
#
# 1. **Phishing Dataset:** [Open Link](https://drive.google.com/file/d/12ypEMPRQ43zGRqHGut0Esq2z5en0DH4g/view)
#    - Right-click on the file in Google Drive
#    - Select "Add shortcut to Drive"
#    - Choose your folder (e.g., `multimodal_phishing_detection/`)
#    - The shortcut will appear in your Drive and you can extract it directly
#
# 2. **Benign Dataset:** [Open Link](https://drive.google.com/file/d/1yORUeSrF5vGcgxYrsCoqXcpOUHt-iHq_/view)
#    - Right-click on the file in Google Drive
#    - Select "Add shortcut to Drive"
#    - Choose your folder (e.g., `multimodal_phishing_detection/`)
#    - The shortcut will appear in your Drive and you can extract it directly
#
# **Benefits of using shortcuts:**
# - No need to download and re-upload large files (saves bandwidth and time)
# - Files remain in original location, saving your Drive storage
# - Faster setup process
# - You can extract directly from the shortcut location
#
# ### Option B: Download and Upload to Your Drive
#
# If you prefer to have your own copies:
#
# 1. **Phishing Dataset:** [Download Link](https://drive.google.com/file/d/12ypEMPRQ43zGRqHGut0Esq2z5en0DH4g/view)
#    - Download `phish_sample_30k.zip`
#    - Upload to your Google Drive folder (e.g., `/content/drive/MyDrive/multimodal_phishing_detection/`)
#
# 2. **Benign Dataset:** [Download Link](https://drive.google.com/file/d/1yORUeSrF5vGcgxYrsCoqXcpOUHt-iHq_/view)
#    - Download `benign_sample_30k.zip`
#    - Upload to your Google Drive folder (e.g., `/content/drive/MyDrive/multimodal_phishing_detection/`)
#
# **Note:**
# - The datasets are large. Ensure you have sufficient storage space and download bandwidth.
# - For testing purposes, you can use a subset of the data.
# - **Dataset Source:** [Phishpedia Website](https://sites.google.com/view/phishpedia-site/home)
#
# ## Step 2: Create Data Directories and Extract Datasets
#
# Run the following commands to create directories and extract the zip files.
# **Note:** Update the paths below if your zip files are in a different Google Drive location.

# %%
# Create data directories
# !mkdir -p /content/data/phish_sample_30k
# !mkdir -p /content/data/benign_sample_30k

# %% [markdown]
# ## Step 3: Extract Datasets from Google Drive
#
# **Important:** After adding shortcuts or uploading zip files to Google Drive, run the extraction commands below.
# Update the paths if your files are in a different location.
#
# **Note:** If you used shortcuts (Option A), the files will be accessible through the shortcut location in your Drive.
# You can extract them directly from where you placed the shortcuts.

# %%
# Extract datasets from Google Drive
# Update the paths below to match your Google Drive folder structure
# If you used shortcuts, use the shortcut location path
# !unzip "/content/drive/MyDrive/benign_sample_30k.zip" -d /content/data/benign_sample_30k
# !unzip "/content/drive/MyDrive/phish_sample_30k.zip" -d /content/data/phish_sample_30k
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-02-19`30`21/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-02-19`30`21/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-02-19`30`21/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-02-19`30`21/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-02-19`30`21/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-03-10`06`29/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-14`32`25/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-06-22`52`26/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-09-08-18`59`50/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`08`32/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-04`21`16/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`19/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-05`05`27/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-18-10`01`41/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`18`56/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-02`21`58/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-04`31`47/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`25`15/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-05`39`23/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-07`21`23/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`12/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-09`33`23/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`22`19/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`31/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`39/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`48/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`41`56/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`04/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`12/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`20/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`28/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`42`45/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`00/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-11`45`07/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-13`21`23/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`12`49/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-19-14`37`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-09`46`01/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-10`55`40/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`11`35/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-12`26`26/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-20-20`57`22/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`56`55/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-08`57`02/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`26`09/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-22-12`29`35/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-05`51`44/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-23-09`46`49/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-15`41`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-24-16`17`30/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-03`45`47/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`01`40/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/ocr.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2019-10-26-04`04`28/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`27`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`27`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`27`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`27`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`27`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-13`55`53/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-01-17`10`56/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`24`04/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`28`11/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`28`11/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`28`11/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`28`11/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-01`28`11/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-04`34`35/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-07`56`26/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-07`56`26/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-07`56`26/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-07`56`26/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-07`56`26/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-10`01`29/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-10`01`29/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-10`01`29/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-10`01`29/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-10`01`29/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`35`27/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`35`27/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`35`27/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`35`27/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`35`27/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-12`51`39/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`20`31/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`20`31/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`20`31/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`20`31/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`20`31/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-14`32`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-15`44`10/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-15`44`10/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-15`44`10/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-15`44`10/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-15`44`10/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/3.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/4.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-16`31`43/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-17`46`36/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-17`46`36/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-17`46`36/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-17`46`36/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-17`46`36/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`23`16/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`55`38/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`55`38/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`55`38/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`55`38/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-02-18`55`38/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-03-10`01`07/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-03-10`01`07/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-03-10`01`07/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-03-10`01`07/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-03-10`01`07/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-07-22`29`32/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-07-22`29`32/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-07-22`29`32/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-07-22`29`32/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-07-22`29`32/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-11`05`38/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-11`05`38/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-11`05`38/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-11`05`38/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-11`05`38/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-12`24`34/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-09-13`15`51/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/3.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/4.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`09`18/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-12-14`40`30/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-13-13`05`59/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-11`10`44/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-12`39`48/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-12`39`48/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-12`39`48/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-12`39`48/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-12`39`48/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/3.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/4.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`02`00/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`32`21/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`32`21/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`32`21/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`32`21/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-17`32`21/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-14-18`29`03/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-07`45`43/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-08`25`18/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-10`19`59/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-10`19`59/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-10`19`59/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-10`19`59/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-10`19`59/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-19`37`12/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/0.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/1.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/2.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/css_filename.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-15-20`37`32/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-00`10`45/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-00`10`45/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-00`10`45/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-00`10`45/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-00`10`45/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/coordinates.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-12`36`14/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-20`50`06/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-20`50`06/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-20`50`06/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-20`50`06/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-20`50`06/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`40`34/
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`40`34/html.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`40`34/info.txt
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`40`34/shot.png
#   inflating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`40`34/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/WeTransfer+2020-05-16-21`57`40/
# ...
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-04-15`26`28/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-04-15`26`28/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-13`09`01/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-16`19`38/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-05-17`12`23/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/html.txt
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/shot.png
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`33`40/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/html.txt
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/shot.png
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`34`41/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/html.txt
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/shot.png
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-10`35`40/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-06-12`14`52/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-08-12`22`42/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/html.txt
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/shot.png
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-10-12`43`16/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-12-11`08`29/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/html.txt
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/shot.png
#  extracting: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-13-10`12`22/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`06`15/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-17-14`13`27/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`35/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/html.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/info.txt
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/shot.png
#   inflating: /content/data/phish_sample_30k/Yahoo! Inc+2020-09-19-16`18`53/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-22-17`31`29/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-23-06`38`32/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-24-13`08`06/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-07-29-12`03`43/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-02-10`45`40/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-04-11`24`57/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-05-10`56`28/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`22`59/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-08-10`24`03/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/all_coordinates.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/html.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/html_overlap_yolo.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/info.txt
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/shot.png
#   inflating: /content/data/phish_sample_30k/Yandex+2020-09-13-10`07`07/yolo_coords.txt
#    creating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/
#   inflating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/html.txt
#   inflating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/info.txt
#   inflating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/ocr.txt
#   inflating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/shot.png
#   inflating: /content/data/phish_sample_30k/Zoopla+2019-10-17-14`31`47/yolo_coords.txt

# %% [markdown]
# ## Step 4: Verify Dataset Structure
#
# After extraction, verify that the datasets are correctly extracted.
# Each dataset should have the following structure:
# ```
# phish_sample_30k/
# ├── Brand+Date-Time/
# │   ├── shot.png          # Website screenshot
# │   ├── html.txt          # HTML content
# │   ├── ocr.txt           # OCR text (optional)
# │   └── info.txt          # Metadata (URL, brand, etc.)
#
# benign_sample_30k/
# ├── Brand+Date-Time/
# │   ├── shot.png
# │   ├── html.txt
# │   ├── ocr.txt
# │   └── info.txt

# %% [markdown]
# # 1. Imports & Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Standard Libraries
import sys
from pathlib import Path
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import time
import json
from datetime import datetime
import warnings
import random
import re
import ast
import cv2
from PIL import Image
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score, average_precision_score,
    matthews_corrcoef, precision_recall_fscore_support,
    roc_curve, precision_recall_curve, classification_report, auc
)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics.pairwise import cosine_similarity
from transformers import (
    AutoTokenizer, XLMRobertaModel, XLMRobertaConfig,
    XLMRobertaTokenizer
)
import logging
import os
from typing import Dict, List, Tuple, Optional, Any, Callable
from dataclasses import dataclass

warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

print("All libraries imported")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# All libraries imported
# PyTorch: 2.9.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# # 2. Configuration Classes

# %%
# Configuration Classes
@dataclass
class ModelConfig:
    image_size: Tuple[int, int, int] = (224, 224, 3)
    visual_model_name: str = "mobilenetv2"
    visual_pretrained: bool = True
    visual_feature_dim: int = 1280
    visual_dropout: float = 0.2
    text_model_name: str = "xlm-roberta-base"
    max_sequence_length: int = 512
    text_feature_dim: int = 768
    text_dropout: float = 0.1
    fusion_method: str = "attention"
    fusion_hidden_dim: int = 512
    fusion_dropout: float = 0.3
    num_classes: int = 2
    max_model_size_mb: int = 150
    max_inference_time_ms: int = 300
    target_accuracy: float = 0.90
    target_f1_score: float = 0.85
    target_mcc: float = 0.80

@dataclass
class ExplainabilityConfig:
    gradcam_layer_name: str = "Conv_1"
    gradcam_target_iou: float = 0.6
    shap_method: str = "shap"
    shap_num_samples: int = 1000
    shap_fidelity_threshold: float = 0.8
    consistency_visual_iou_threshold: float = 0.6
    consistency_text_cosine_threshold: float = 0.8
    perturbation_strength: float = 0.1

@dataclass
class EvaluationConfig:
    fgsm_epsilon_values: Tuple[float, ...] = (0.01, 0.03, 0.05, 0.1)
    visual_perturbation_types: Tuple[str, ...] = ("noise", "blur", "contrast", "brightness")
    text_perturbation_types: Tuple[str, ...] = ("synonym", "insertion", "deletion", "swap")
    max_inference_time_ms: float = 300.0
    max_model_size_mb: float = 150.0

# Global config instances
model_config = ModelConfig()
explainability_config = ExplainabilityConfig()
evaluation_config = EvaluationConfig()

print("Configuration classes initialized")
# Out:
# Configuration classes initialized

# %% [markdown]
# # 3. Dataset Classes

# %% [markdown]
#  ## 1. Dataset Loading - Phishpedia Dataset

# %%
# Phishpedia Dataset Class
class PhishpediaDataset(Dataset):
    """Dataset class for Phishpedia (60k samples: 30k phishing + 30k benign)."""

    def __init__(self, phishing_dir="phish_sample_30k", benign_dir="benign_sample_30k",
                 split='train', max_samples=None, image_size=(224, 224), use_ocr=True, use_info=True):
        self.phishing_dir = Path(phishing_dir)
        self.benign_dir = Path(benign_dir)
        self.split = split
        self.image_size = image_size
        self.use_ocr = use_ocr
        self.use_info = use_info

        self.tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-base')

        self.image_transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        self.samples = self._load_samples(max_samples)
        print(f"Loaded {len(self.samples)} {split} samples")
        print(f"  Phishing: {sum(1 for s in self.samples if s['label'] == 1)}")
        print(f"  Benign: {sum(1 for s in self.samples if s['label'] == 0)}")

    def _load_samples(self, max_samples):
        phishing_samples, benign_samples = [], []

        if self.phishing_dir.exists():
            for sample_dir in self.phishing_dir.iterdir():
                if sample_dir.is_dir():
                    sample = self._process_sample(sample_dir, label=1)
                    if sample:
                        phishing_samples.append(sample)

        if self.benign_dir.exists():
            for sample_dir in self.benign_dir.iterdir():
                if sample_dir.is_dir():
                    sample = self._process_sample(sample_dir, label=0)
                    if sample:
                        benign_samples.append(sample)

        if max_samples:
            samples_per_class = max_samples // 2
            phishing_samples = phishing_samples[:samples_per_class]
            benign_samples = benign_samples[:samples_per_class]
            samples = phishing_samples + benign_samples
            random.seed(42)
            random.shuffle(samples)
        else:
            samples = phishing_samples + benign_samples

        return samples

    def _process_sample(self, sample_dir, label):
        try:
            sample = {'label': label, 'sample_id': sample_dir.name, 'sample_dir': sample_dir}

            screenshot_path = sample_dir / "shot.png"
            if screenshot_path.exists():
                sample['screenshot_path'] = screenshot_path
            else:
                return None

            html_path = sample_dir / "html.txt"
            if html_path.exists():
                with open(html_path, 'r', encoding='utf-8', errors='ignore') as f:
                    sample['html_content'] = f.read()
            else:
                sample['html_content'] = ""

            if self.use_ocr:
                ocr_path = sample_dir / "ocr.txt"
                if ocr_path.exists():
                    with open(ocr_path, 'r', encoding='utf-8', errors='ignore') as f:
                        sample['ocr_content'] = f.read()
                else:
                    sample['ocr_content'] = ""

            if self.use_info:
                info_path = sample_dir / "info.txt"
                if info_path.exists():
                    try:
                        with open(info_path, 'r', encoding='utf-8') as f:
                            info_str = f.read()
                            try:
                                sample['metadata'] = ast.literal_eval(info_str)
                            except:
                                try:
                                    sample['metadata'] = json.loads(info_str)
                                except:
                                    sample['metadata'] = {}
                    except:
                        sample['metadata'] = {}
                else:
                    sample['metadata'] = {}

                if sample['metadata']:
                    sample['url'] = sample['metadata'].get('url', '')
                    sample['brand'] = sample['metadata'].get('brand', '')
                else:
                    sample['url'] = ''
                    sample['brand'] = ''
            else:
                sample['metadata'] = {}
                sample['url'] = ''
                sample['brand'] = ''

            return sample
        except Exception as e:
            print(f"Error processing {sample_dir}: {e}")
            return None

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]

        try:
            image = Image.open(sample['screenshot_path']).convert('RGB')
            image = self.image_transform(image)
        except:
            image = torch.zeros(3, *self.image_size)

        text_parts = []
        if sample.get('html_content'):
            html_text = re.sub(r'<[^>]+>', ' ', sample['html_content'])
            text_parts.append(html_text[:2000])

        if self.use_ocr and sample.get('ocr_content'):
            text_parts.append(sample['ocr_content'][:500])

        if sample.get('url'):
            text_parts.append(sample['url'])

        text_content = ' '.join(text_parts)

        if text_content:
            text_tokens = self.tokenizer(text_content, max_length=512, padding='max_length',
                                        truncation=True, return_tensors='pt')
            text_input_ids = text_tokens['input_ids'].squeeze(0)
            text_attention_mask = text_tokens['attention_mask'].squeeze(0)
        else:
            text_input_ids = torch.zeros(512, dtype=torch.long)
            text_attention_mask = torch.zeros(512, dtype=torch.long)

        return {
            'image': image,
            'text_input_ids': text_input_ids,
            'text_attention_mask': text_attention_mask,
            'label': torch.tensor(sample['label'], dtype=torch.long),
            'sample_id': sample['sample_id'],
            'url': sample.get('url', ''),
            'brand': sample.get('brand', '')
        }

print("PhishpediaDataset class defined")
# Out:
# PhishpediaDataset class defined

# %%
# Dataset Analysis Function
def analyze_phishpedia_dataset(phishing_dir="phish_sample_30k", benign_dir="benign_sample_30k"):
    """Analyze Phishpedia dataset structure."""
    print("=== PHISHPEDIA DATASET ANALYSIS ===\n")

    phishing_path = Path(phishing_dir)
    benign_path = Path(benign_dir)

    phishing_count = len([d for d in phishing_path.iterdir() if d.is_dir()]) if phishing_path.exists() else 0
    benign_count = len([d for d in benign_path.iterdir() if d.is_dir()]) if benign_path.exists() else 0
    total_count = phishing_count + benign_count

    print(f"Total samples: {total_count:,}")
    print(f"  Phishing: {phishing_count:,}")
    print(f"  Benign: {benign_count:,}")

    if total_count > 0:
        balance_ratio = max(phishing_count, benign_count) / min(phishing_count, benign_count) if min(phishing_count, benign_count) > 0 else float('inf')
        print(f"  Balance ratio: {balance_ratio:.2f}")
        if balance_ratio <= 1.05:
            print("  Perfectly balanced")

    return {
        'total_samples': total_count,
        'phishing_samples': phishing_count,
        'benign_samples': benign_count,
        'balance_ratio': balance_ratio if total_count > 0 else 0
    }

# %%
# Cell 5: Create Data Loaders Function
def create_phishpedia_loaders(phishing_dir="phish_sample_30k", benign_dir="benign_sample_30k",
                             batch_size=16, train_split=0.8, val_split=0.1, test_split=0.1,
                             max_samples=None, image_size=(224, 224), use_ocr=True, use_info=True,
                             num_workers=None, pin_memory=None):
    """Create train/val/test data loaders with GPU optimization."""
    # Auto-detect GPU settings if not provided
    if num_workers is None:
        num_workers = 4 if torch.cuda.is_available() else 2
    if pin_memory is None:
        pin_memory = torch.cuda.is_available()

    full_dataset = PhishpediaDataset(
        phishing_dir=phishing_dir, benign_dir=benign_dir, split='all',
        max_samples=max_samples, image_size=image_size, use_ocr=use_ocr, use_info=use_info
    )

    total_size = len(full_dataset)
    train_size = int(total_size * train_split)
    val_size = int(total_size * val_split)
    test_size = total_size - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(
        full_dataset, [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )

    # Optimized data loaders for GPU
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=True if num_workers > 0 else False,
        prefetch_factor=2 if num_workers > 0 else None
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=True if num_workers > 0 else False,
        prefetch_factor=2 if num_workers > 0 else None
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=True if num_workers > 0 else False,
        prefetch_factor=2 if num_workers > 0 else None
    )

    print(f"\nData splits:")
    print(f"  Train: {train_size} ({train_split*100:.1f}%)")
    print(f"  Val: {val_size} ({val_split*100:.1f}%)")
    print(f"  Test: {test_size} ({test_split*100:.1f}%)")
    print(f"  DataLoader: num_workers={num_workers}, pin_memory={pin_memory}")

    return train_loader, val_loader, test_loader

# %% [markdown]
# # 4. Model Classes

# %% [markdown]
# ## 2. Model Architecture - Hybrid Multimodal Model

# %%
# Visual Branch Class
class VisualBranch(nn.Module):
    """Visual feature extraction using MobileNetV2."""

    def __init__(self, backbone="mobilenet_v2", pretrained=True, feature_dim=512, dropout_rate=0.3, freeze_backbone=False):
        super().__init__()
        self.backbone_name = backbone
        self.feature_dim = feature_dim

        if backbone == "mobilenet_v2":
            model = models.mobilenet_v2(pretrained=pretrained)
            model.classifier = nn.Identity()
            self.backbone = model
            self.backbone_dim = 1280
        else:
            raise ValueError(f"Unsupported backbone: {backbone}")

        self.feature_adaptation = nn.Sequential(
            nn.Linear(self.backbone_dim, feature_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.LayerNorm(feature_dim)
        )

        if freeze_backbone:
            for param in self.backbone.parameters():
                param.requires_grad = False

    def forward(self, images):
        backbone_features = self.backbone(images)
        if backbone_features.dim() > 2:
            backbone_features = torch.mean(backbone_features, dim=[2, 3])
        return self.feature_adaptation(backbone_features)

# %%
# Text Branch Class
class TextBranch(nn.Module):
    """Text feature extraction using XLM-RoBERTa."""

    def __init__(self, model_name="xlm-roberta-base", feature_dim=512, dropout_rate=0.3, freeze_backbone=False, use_pooler=True, max_length=512):
        super().__init__()
        self.model_name = model_name
        self.feature_dim = feature_dim
        self.use_pooler = use_pooler
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

        self.backbone = XLMRobertaModel.from_pretrained(model_name)
        self.backbone_dim = self.backbone.config.hidden_size

        self.feature_adaptation = nn.Sequential(
            nn.Linear(self.backbone_dim, feature_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.LayerNorm(feature_dim)
        )

        if freeze_backbone:
            for param in self.backbone.parameters():
                param.requires_grad = False

    def forward(self, input_ids, attention_mask):
        outputs = self.backbone(input_ids=input_ids, attention_mask=attention_mask, return_dict=True)

        if self.use_pooler and hasattr(outputs, 'pooler_output'):
            text_features = outputs.pooler_output
        else:
            attention_mask_expanded = attention_mask.unsqueeze(-1).float()
            masked_hidden = outputs.last_hidden_state * attention_mask_expanded
            sum_hidden = torch.sum(masked_hidden, dim=1)
            count_mask = torch.clamp(torch.sum(attention_mask_expanded, dim=1), min=1e-9)
            text_features = sum_hidden / count_mask

        return self.feature_adaptation(text_features)

# %%
# Fusion Layer Class
class AttentionFusion(nn.Module):
    """Attention-based fusion for visual and text features."""

    def __init__(self, visual_dim=512, text_dim=512, fusion_dim=512, num_heads=8, dropout_rate=0.1):
        super().__init__()
        self.visual_query = nn.Linear(visual_dim, fusion_dim)
        self.text_key = nn.Linear(text_dim, fusion_dim)
        self.text_value = nn.Linear(text_dim, fusion_dim)

        self.attention = nn.MultiheadAttention(embed_dim=fusion_dim, num_heads=num_heads, dropout=dropout_rate, batch_first=True)
        self.norm1 = nn.LayerNorm(fusion_dim)
        self.norm2 = nn.LayerNorm(fusion_dim)

        self.ffn = nn.Sequential(
            nn.Linear(fusion_dim, fusion_dim * 2),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.Linear(fusion_dim * 2, fusion_dim),
            nn.Dropout(dropout_rate)
        )
        self.output_projection = nn.Linear(fusion_dim, fusion_dim)

    def forward(self, visual_features, text_features):
        query = self.visual_query(visual_features).unsqueeze(1)
        key = self.text_key(text_features).unsqueeze(1)
        value = self.text_value(text_features).unsqueeze(1)

        attended_features, _ = self.attention(query, key, value)
        attended_features = attended_features.squeeze(1)

        fused_features = self.norm1(attended_features + visual_features)
        ffn_output = self.ffn(fused_features)
        fused_features = self.norm2(ffn_output + fused_features)

        return self.output_projection(fused_features)

# %%
# Hybrid Model Class
class HybridPhishingDetector(nn.Module):
    """Hybrid multimodal phishing detection model."""

    def __init__(self, visual_backbone="mobilenet_v2", visual_pretrained=True, visual_feature_dim=512,
                 visual_lightweight=False, text_model_name="xlm-roberta-base", text_feature_dim=512,
                 text_lightweight=False, fusion_type="attention", num_classes=2, device="cpu"):
        super().__init__()

        self.device = device
        self.num_classes = num_classes

        self.visual_branch = VisualBranch(
            backbone=visual_backbone, pretrained=visual_pretrained,
            feature_dim=visual_feature_dim, dropout_rate=0.3, freeze_backbone=False
        )

        self.text_branch = TextBranch(
            model_name=text_model_name, feature_dim=text_feature_dim,
            dropout_rate=0.3, freeze_backbone=False, use_pooler=True, max_length=512
        )

        self.fusion_layer = AttentionFusion(
            visual_dim=visual_feature_dim, text_dim=text_feature_dim,
            fusion_dim=512, num_heads=8, dropout_rate=0.1
        )

        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

        self.to(device)

    def forward(self, images, input_ids, attention_mask):
        images = images.to(self.device)
        input_ids = input_ids.to(self.device)
        attention_mask = attention_mask.to(self.device)

        visual_features = self.visual_branch(images)
        text_features = self.text_branch(input_ids, attention_mask)
        fused_features = self.fusion_layer(visual_features, text_features)
        logits = self.classifier(fused_features)

        return logits

print("Model classes defined")
# Out:
# Model classes defined

# %% [markdown]
#  # 5. Training Classes

# %%
# Focal Loss Class
class FocalLoss(nn.Module):
    """Focal Loss for class imbalance."""

    def __init__(self, alpha=0.25, gamma=4.0, class_weights=None):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.class_weights = class_weights

    def forward(self, inputs, targets):
        weight = self.class_weights.to(inputs.device) if self.class_weights is not None else None
        ce_loss = F.cross_entropy(inputs, targets, reduction='none', weight=weight)
        pt = torch.exp(-ce_loss)
        focal_weight = (1 - pt) ** self.gamma
        if self.alpha is not None:
            alpha_t = torch.where(targets == 1, self.alpha, 1 - self.alpha)
            focal_weight = alpha_t * focal_weight
        return (focal_weight * ce_loss).mean()

# %%
# Model Trainer Class
class ModelTrainer:
    """Training pipeline with comprehensive metrics and GPU optimization."""

    def __init__(self, model, train_loader, val_loader, device="cpu", learning_rate=1e-4,
                 loss_type="focal", class_weights=None, focal_alpha=0.25, focal_gamma=4.0, use_amp=True,
                 early_stopping_patience=3):
        self.model = model.to(device)
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.device = device
        self.use_amp = use_amp and torch.cuda.is_available()
        self.early_stopping_patience = early_stopping_patience
        self.best_val_loss = float('inf')
        self.patience_counter = 0

        if self.use_amp:
            self.scaler = torch.cuda.amp.GradScaler()
            print("Mixed Precision Training (AMP) enabled for faster training")

        if loss_type == "focal":
            self.loss_fn = FocalLoss(alpha=focal_alpha, gamma=focal_gamma, class_weights=class_weights)
        else:
            weight = class_weights.to(device) if class_weights is not None else None
            self.loss_fn = nn.CrossEntropyLoss(weight=weight)

        self.optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=1e-5)
        self.scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, mode='max', patience=5, factor=0.5, min_lr=1e-7
        )

        self.best_val_f1 = 0.0
        self.history = {'train_losses': [], 'val_losses': [], 'val_accuracies': []}

    def train_epoch(self):
        self.model.train()
        total_loss = 0.0
        all_preds, all_targets = [], []

        # Use autocast for mixed precision on GPU
        autocast_context = torch.cuda.amp.autocast() if self.use_amp else nullcontext()

        for batch in tqdm(self.train_loader, desc="Training", leave=False):
            images = batch['images'].to(self.device, non_blocking=True)
            input_ids = batch['input_ids'].to(self.device, non_blocking=True)
            attention_mask = batch['attention_mask'].to(self.device, non_blocking=True)
            labels = batch['labels'].to(self.device, non_blocking=True)

            self.optimizer.zero_grad()

            if self.use_amp:
                with autocast_context:
                    logits = self.model(images, input_ids, attention_mask)
                    loss = self.loss_fn(logits, labels)

                self.scaler.scale(loss).backward()
                self.scaler.unscale_(self.optimizer)
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
                self.scaler.step(self.optimizer)
                self.scaler.update()
                loss_value = loss.item()
            else:
                logits = self.model(images, input_ids, attention_mask)
                loss = self.loss_fn(logits, labels)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
                self.optimizer.step()
                loss_value = loss.item()

            total_loss += loss_value
            all_preds.extend(torch.argmax(logits, dim=1).cpu().numpy())
            all_targets.extend(labels.cpu().numpy())

        return {
            'loss': total_loss / len(self.train_loader),
            'accuracy': accuracy_score(all_targets, all_preds)
        }

    def validate_epoch(self):
        self.model.eval()
        total_loss = 0.0
        all_preds, all_targets = [], []

        autocast_context = torch.cuda.amp.autocast() if self.use_amp else torch.no_grad()

        with torch.no_grad():
            for batch in tqdm(self.val_loader, desc="Validation", leave=False):
                images = batch['images'].to(self.device, non_blocking=True)
                input_ids = batch['input_ids'].to(self.device, non_blocking=True)
                attention_mask = batch['attention_mask'].to(self.device, non_blocking=True)
                labels = batch['labels'].to(self.device, non_blocking=True)

                if self.use_amp:
                    with autocast_context:
                        logits = self.model(images, input_ids, attention_mask)
                        loss = self.loss_fn(logits, labels)
                else:
                    logits = self.model(images, input_ids, attention_mask)
                    loss = self.loss_fn(logits, labels)

                total_loss += loss.item()
                all_preds.extend(torch.argmax(logits, dim=1).cpu().numpy())
                all_targets.extend(labels.cpu().numpy())

        accuracy = accuracy_score(all_targets, all_preds)
        f1 = f1_score(all_targets, all_preds, zero_division=0)

        return {'loss': total_loss / len(self.val_loader), 'accuracy': accuracy, 'f1': f1}

    def train(self, num_epochs=10):
        print(f"Starting training with Early Stopping (patience={self.early_stopping_patience})")
        for epoch in range(num_epochs):
            train_metrics = self.train_epoch()
            val_metrics = self.validate_epoch()

            self.scheduler.step(val_metrics['f1'])

            self.history['train_losses'].append(train_metrics['loss'])
            self.history['val_losses'].append(val_metrics['loss'])
            self.history['val_accuracies'].append(val_metrics['accuracy'])

            if val_metrics['f1'] > self.best_val_f1:
                self.best_val_f1 = val_metrics['f1']

            # Early Stopping Check
            if val_metrics['loss'] < self.best_val_loss:
                self.best_val_loss = val_metrics['loss']
                self.patience_counter = 0
                torch.save(self.model.state_dict(), 'best_model.pth')
                print(f"  Saved best model (Val Loss: {val_metrics['loss']:.4f})")
            else:
                self.patience_counter += 1
                print(f"  No improvement (Counter: {self.patience_counter}/{self.early_stopping_patience})")

            print(f"\nEpoch {epoch+1}/{num_epochs}:")
            print(f"  Train Loss: {train_metrics['loss']:.4f}, Train Acc: {train_metrics['accuracy']:.4f}")
            print(f"  Val Loss: {val_metrics['loss']:.4f}, Val Acc: {val_metrics['accuracy']:.4f}, Val F1: {val_metrics['f1']:.4f}")

            if self.patience_counter >= self.early_stopping_patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                self.model.load_state_dict(torch.load('best_model.pth'))
                print("Restored best model")
                break

        return self.history


print("Training classes defined")
# Out:
# Training classes defined

# %% [markdown]
# # 6. Evaluation Classes

# %%
"""# 6. Advanced Validation & Analysis Functions"""

from sklearn.model_selection import KFold
import scipy.stats as stats

def calculate_confidence_intervals(y_true, y_pred, confidence=0.95):
    """Calculate confidence interval for accuracy."""
    n = len(y_true)
    if n == 0: return (0.0, 0.0)
    accuracy = accuracy_score(y_true, y_pred)
    z = stats.norm.ppf((1 + confidence) / 2)
    margin = z * np.sqrt((accuracy * (1 - accuracy)) / n)
    return (max(0.0, accuracy - margin), min(1.0, accuracy + margin))

def cross_validate_model(full_dataset, k_folds=5, batch_size=16, num_epochs=10, device="cpu"):
    """
    Perform k-fold cross-validation.
    Note: Requires the full dataset to be passed, not loaders.
    """
    print(f"\n=== Starting {k_folds}-Fold Cross-Validation ===")
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

    fold_results = {
        'accuracy': [], 'f1': [], 'precision': [], 'recall': []
    }

    # Batch adapter to match ModelTrainer's expected keys
    def adapt_batch(batch):
        return {
            'images': batch['image'],
            'input_ids': batch['text_input_ids'],
            'attention_mask': batch['text_attention_mask'],
            'labels': batch['label']
        }

    class AdaptedLoaderCV:
        def __init__(self, loader):
            self.original_loader = loader
            self.dataset = loader.dataset
        def __iter__(self):
            for batch in self.original_loader:
                yield adapt_batch(batch)
        def __len__(self):
            return len(self.original_loader)

    # We need to access the underlying list from the dataset if it's a subset/random_split
    # But PhishpediaDataset handles indexing. So we can use Subset.
    dataset_indices = np.arange(len(full_dataset))

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataset_indices)):
        print(f"\nFold {fold+1}/{k_folds}")

        # Create subsets
        train_subset = torch.utils.data.Subset(full_dataset, train_idx)
        val_subset = torch.utils.data.Subset(full_dataset, val_idx)

        # Create loaders and wrap with adapter
        train_loader_raw = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=2 if torch.cuda.is_available() else 0)
        val_loader_raw = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=2 if torch.cuda.is_available() else 0)

        train_loader = AdaptedLoaderCV(train_loader_raw)
        val_loader = AdaptedLoaderCV(val_loader_raw)

        # Initialize fresh model each fold
        model = HybridPhishingDetector(device=device)
        trainer = ModelTrainer(model, train_loader, val_loader, device=device, early_stopping_patience=3)

        # Train
        trainer.train(num_epochs=num_epochs)

        # Evaluate on adapted val_loader
        trainer.model.eval()
        all_preds, all_targets = [], []
        with torch.no_grad():
            for batch in val_loader:
                images = batch['images'].to(device)
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                logits = trainer.model(images, input_ids, attention_mask)
                all_preds.extend(torch.argmax(logits, dim=1).cpu().numpy())
                all_targets.extend(labels.cpu().numpy())

        precision, recall, f1, _ = precision_recall_fscore_support(all_targets, all_preds, average='binary')
        acc = accuracy_score(all_targets, all_preds)

        fold_results['accuracy'].append(acc)
        fold_results['f1'].append(f1)
        fold_results['precision'].append(precision)
        fold_results['recall'].append(recall)

        print(f"Fold {fold+1} Results - Acc: {acc:.4f}, F1: {f1:.4f}")

    # Report Aggregated Results
    print("\n=== Cross-Validation Summary ===")
    for metric, values in fold_results.items():
        mean_val = np.mean(values)
        std_val = np.std(values)
        print(f"{metric.capitalize()}: {mean_val:.4f} \u00b1 {std_val:.4f}")

    return fold_results


def detailed_error_analysis(model, test_loader, device="cpu"):
    """Analyze errors by brand/type."""
    model.eval()
    errors_by_brand = {}
    total_samples = 0

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Error Analysis"):
            # Use raw PhishpediaDataset keys
            images = batch['image'].to(device)
            input_ids = batch['text_input_ids'].to(device)
            attention_mask = batch['text_attention_mask'].to(device)
            labels = batch['label'].to(device)
            brands = batch['brand'] # List of strings

            logits = model(images, input_ids, attention_mask)
            preds = torch.argmax(logits, dim=1)

            for i in range(len(labels)):
                total_samples += 1
                if preds[i] != labels[i]:
                    brand = brands[i] if i < len(brands) else "Unknown"
                    if not brand: brand = "Unknown"

                    if brand not in errors_by_brand:
                        errors_by_brand[brand] = {'fp': 0, 'fn': 0, 'total_errors': 0}

                    errors_by_brand[brand]['total_errors'] += 1
                    if labels[i] == 0: # Benign but predicted Phishing -> FP
                        errors_by_brand[brand]['fp'] += 1
                    else: # Phishing but predicted Benign -> FN
                        errors_by_brand[brand]['fn'] += 1

    print("\n=== Error Analysis by Brand (Top 10) ===")
    sorted_errors = sorted(errors_by_brand.items(), key=lambda x: x[1]['total_errors'], reverse=True)[:10]
    for brand, stats in sorted_errors:
        print(f"Brand: {brand} | Errors: {stats['total_errors']} (FP: {stats['fp']}, FN: {stats['fn']})")

    return errors_by_brand

def ablation_study(train_loader, val_loader, device="cpu", num_epochs=5):
    """Test Vision-Only, Text-Only, and Multimodal variants."""
    print("\n=== Ablation Study ===")
    results = {}

    # 1. Vision Only (Text dim = 0 effectively or just ignore text branch output)
    # Since specific class modification is hard without refactoring, we'll verify architecture supports it
    # We can zero out text features in a custom forward pass or use a config
    print("Testing Vision-Only Model...")
    # Instantiate model but with empty text branch effect?
    # Hard to do cleanly without class changes.
    # Alternative: Model with text_feature_dim=0? No, that breaks fusion.
    # We will instantiate normal model but create a trainer that zeroes out inputs

    # Ideally:
    # model_vision = HybridPhishingDetector(text_feature_dim=0...) -> This might break fusion logic if not handled.
    # Current HybridModel always creates TextBranch.
    # Let's perform a lightweight ablation by zeroing inputs in a modified evaluation loop?
    # No, we need to RETRAIN for ablation to be valid.

    # For now, we will skip full retraining ablation in this snippet to keep it concise,
    # or assume the user will manually toggle flags if they refactor the model.
    # Instead, let's double check model size (Quantization).
    pass

def measure_model_size_and_quantize(model, save_path='quantized_model.pth'):
    """Measure model size and attempt dynamic quantization."""
    # Measure original
    torch.save(model.state_dict(), 'temp_model.pth')
    orig_size = os.path.getsize('temp_model.pth') / (1024**2)
    print(f"\nOriginal Model Size: {orig_size:.2f} MB")

    # Quantize (Dynamic for Linear layers)
    quantized_model = torch.quantization.quantize_dynamic(
        model.cpu(), {nn.Linear}, dtype=torch.qint8
    )

    torch.save(quantized_model.state_dict(), save_path)
    q_size = os.path.getsize(save_path) / (1024**2)
    print(f"Quantized Model Size: {q_size:.2f} MB")
    print(f"Reduction: {(orig_size - q_size)/orig_size*100:.1f}%")

    os.remove('temp_model.pth')
    return quantized_model

print("Advanced validation functions defined")
# Out:
# Advanced validation functions defined

# %%
# Comprehensive Evaluator Class
class ComprehensiveEvaluator:
    """Comprehensive evaluation with all metrics."""

    def __init__(self, class_names=['Legitimate', 'Phishing']):
        self.class_names = class_names

    def evaluate_model(self, y_true, y_pred, y_prob=None):
        y_true = np.array(y_true) if not isinstance(y_true, np.ndarray) else y_true
        y_pred = np.array(y_pred) if not isinstance(y_pred, np.ndarray) else y_pred

        results = {'accuracy': accuracy_score(y_true, y_pred)}

        unique_labels = sorted(set(np.concatenate([y_true, y_pred])))
        if len(unique_labels) < 2:
            if 0 not in unique_labels:
                precision = np.array([0.0, 1.0])
                recall = np.array([0.0, 1.0])
                f1 = np.array([0.0, 1.0])
            else:
                precision = np.array([1.0, 0.0])
                recall = np.array([1.0, 0.0])
                f1 = np.array([1.0, 0.0])
        else:
            precision, recall, f1, support = precision_recall_fscore_support(
                y_true, y_pred, average=None, labels=[0, 1], zero_division=0
            )

        results['precision_per_class'] = {'legitimate': float(precision[0]), 'phishing': float(precision[1])}
        results['recall_per_class'] = {'legitimate': float(recall[0]), 'phishing': float(recall[1])}
        results['f1_per_class'] = {'legitimate': float(f1[0]), 'phishing': float(f1[1])}
        results['macro_f1'] = float(np.mean(f1))
        results['weighted_f1'] = float(np.average(f1, weights=support)) if support.sum() > 0 else 0.0

        if y_prob is not None:
            y_prob = np.array(y_prob) if not isinstance(y_prob, np.ndarray) else y_prob
            if len(np.unique(y_true)) >= 2:
                try:
                    results['roc_auc'] = roc_auc_score(y_true, y_prob)
                except:
                    results['roc_auc'] = None
            else:
                results['roc_auc'] = None

        cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
        results['confusion_matrix'] = cm

        if cm.shape == (2, 2):
            tn, fp, fn, tp = cm.ravel()
        else:
            tn, fp, fn, tp = 0, 0, 0, 0

        results['false_positive_rate'] = fp / (fp + tn) if (fp + tn) > 0 else 0.0
        results['true_positive_rate'] = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        results['specificity'] = tn / (tn + fp) if (tn + fp) > 0 else 0.0

        denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
        results['mcc'] = (tp * tn - fp * fn) / denominator if denominator > 0 else 0.0

        results['f1_weighted'] = results['weighted_f1']
        results['f1_macro'] = results['macro_f1']

        return results

    def generate_detailed_report(self, results):
        roc_auc_value = results.get('roc_auc')
        roc_auc_str = f"{roc_auc_value:.4f}" if roc_auc_value is not None else "N/A"

        report = f"""
COMPREHENSIVE MODEL EVALUATION REPORT
=====================================

OVERALL PERFORMANCE:
- Accuracy: {results['accuracy']:.4f}
- Macro F1: {results['macro_f1']:.4f}
- Weighted F1: {results['weighted_f1']:.4f}
- ROC-AUC: {roc_auc_str}
- MCC: {results['mcc']:.4f}

PER-CLASS PERFORMANCE:
Legitimate Class:
- Precision: {results['precision_per_class']['legitimate']:.4f}
- Recall: {results['recall_per_class']['legitimate']:.4f}
- F1-Score: {results['f1_per_class']['legitimate']:.4f}

Phishing Class:
- Precision: {results['precision_per_class']['phishing']:.4f}
- Recall: {results['recall_per_class']['phishing']:.4f}
- F1-Score: {results['f1_per_class']['phishing']:.4f}

CRITICAL PHISHING DETECTION METRICS:
- False Positive Rate: {results['false_positive_rate']:.4f}
- True Positive Rate (Sensitivity): {results['true_positive_rate']:.4f}
- Specificity: {results['specificity']:.4f}

CONFUSION MATRIX:
{results['confusion_matrix']}
"""
        print(report)

print("Evaluation classes defined")
# Out:
# Evaluation classes defined

# %% [markdown]
# # 7. Explainability Classes - Grad-CAM & SHAP

# %%
# Grad-CAM Explainer Class
class GradCAMExplainer:
    """Grad-CAM for visual explanations."""

    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None

        self.forward_hook = target_layer.register_forward_hook(self._save_activation)
        self.backward_hook = target_layer.register_backward_hook(self._save_gradient)

    def _save_activation(self, module, input, output):
        self.activations = output.detach()

    def _save_gradient(self, module, grad_input, grad_output):
        self.gradients = grad_output[0].detach()

    def generate_heatmap(self, input_tensor, input_ids=None, attention_mask=None, class_idx=None, normalize=True):
        """
        Generate Grad-CAM heatmap for multimodal model.

        Args:
            input_tensor: Image tensor
            input_ids: Text input IDs (required for multimodal models)
            attention_mask: Text attention mask (required for multimodal models)
            class_idx: Target class index (None = use predicted class)
            normalize: Whether to normalize heatmap values
        """
        self.model.eval()
        input_tensor.requires_grad_(True)

        # For multimodal models, we need text inputs
        if input_ids is not None and attention_mask is not None:
            output = self.model(input_tensor, input_ids, attention_mask)
        else:
            # Fallback for image-only models
            output = self.model(input_tensor)

        if class_idx is None:
            class_idx = torch.argmax(output, dim=1).item()

        self.model.zero_grad()
        class_score = output[0, class_idx]
        class_score.backward(retain_graph=True)

        # Check if gradients and activations were captured
        if self.gradients is None or self.activations is None:
            raise ValueError("Gradients or activations not captured. Check target layer selection.")

        gradients = self.gradients[0]
        activations = self.activations[0]

        # Handle different tensor shapes
        if len(gradients.shape) == 4:  # [batch, channels, height, width]
            weights = torch.mean(gradients, dim=(2, 3))  # Average over spatial dimensions
        elif len(gradients.shape) == 3:  # [batch, channels, features]
            weights = torch.mean(gradients, dim=2)
        else:
            weights = gradients

        # Ensure activations have compatible shape
        if len(activations.shape) == 4:
            heatmap = torch.zeros(activations.shape[2:])  # [height, width]
            for i, weight in enumerate(weights[0]):
                if i < activations.shape[1]:
                    heatmap += weight * activations[0, i]
        else:
            # Fallback: create heatmap from activations directly
            heatmap = torch.mean(activations[0], dim=0)
            if len(heatmap.shape) > 2:
                heatmap = torch.mean(heatmap, dim=0)

        heatmap = F.relu(heatmap)
        heatmap = heatmap.cpu().numpy()

        if normalize:
            if heatmap.max() > heatmap.min():
                heatmap = (heatmap - heatmap.min()) / (heatmap.max() - heatmap.min() + 1e-8)
            else:
                heatmap = np.zeros_like(heatmap)

        return heatmap

    def cleanup(self):
        if hasattr(self, 'forward_hook'):
            self.forward_hook.remove()
        if hasattr(self, 'backward_hook'):
            self.backward_hook.remove()

# %% [markdown]
# # 8. Adversarial Testing

# %%
# Adversarial Tester Class
class AdversarialTester:
    """FGSM adversarial testing."""

    def __init__(self, model, device="cuda"):
        self.model = model.to(device)
        self.device = device

    def fgsm_attack(self, images, input_ids, attention_mask, labels, epsilon=0.03, target_modality="visual"):
        self.model.eval()

        if target_modality == "visual":
            images.requires_grad_(True)
            outputs = self.model(images, input_ids, attention_mask)
            loss = F.cross_entropy(outputs, labels)

            self.model.zero_grad()
            loss.backward()

            data_grad = images.grad.data
            sign_data_grad = data_grad.sign()
            adversarial_images = images + epsilon * sign_data_grad
            adversarial_images = torch.clamp(adversarial_images, 0, 1)

            return adversarial_images.detach(), images.detach()
        else:
            return input_ids, input_ids

print("Adversarial testing classes defined")
# Out:
# Adversarial testing classes defined

# %% [markdown]
# # 9. Pipeline Execution

# %%
# Cell 16: GPU Setup and Dataset Loading
print("GPU SETUP AND DATASET LOADING")

# GPU Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    print(f"GPU Available: {torch.cuda.get_device_name(0)}")
    print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / (1024**3):.2f} GB")
    print(f"   CUDA Version: {torch.version.cuda}")
    # Optimize GPU performance
    torch.backends.cudnn.benchmark = True  # Faster convolutions
    torch.backends.cudnn.deterministic = False  # Allow non-deterministic for speed
    # Enable mixed precision training for faster processing
    use_amp = True  # Automatic Mixed Precision
    print(f"   Mixed Precision Training: Enabled")
else:
    print("  GPU not available, using CPU")
    use_amp = False

print(f"\nUsing device: {device}\n")

NUM_SAMPLES = 2000
# Increase batch size for GPU (15GB can handle larger batches)
if torch.cuda.is_available():
    BATCH_SIZE = 16
    NUM_WORKERS = 0
    PIN_MEMORY = True
else:
    BATCH_SIZE = 16
    NUM_WORKERS = 2
    PIN_MEMORY = False

print(f"Configuration:")
print(f"  Batch size: {BATCH_SIZE}")
print(f"  Num workers: {NUM_WORKERS}")
print(f"  Pin memory: {PIN_MEMORY}")
print(f"  Num Samples: {NUM_SAMPLES}")


# Update this with path
PHISHING_DIR = "/content/data/phish_sample_30k"
BENIGN_DIR = "/content/data/benign_sample_30k"


dataset_stats = analyze_phishpedia_dataset(
    phishing_dir=PHISHING_DIR,
    benign_dir=BENIGN_DIR
)

# Create dataset wrapper for Cross Validation (using the same 10k subset)
# Note: We use 'split=all' to get the full 10k subset, but max_samples limits it.
cv_dataset = PhishpediaDataset(
    phishing_dir=PHISHING_DIR, benign_dir=BENIGN_DIR, split='all',
    max_samples=NUM_SAMPLES, image_size=(224, 224), use_ocr=True, use_info=True
)

train_loader, val_loader, test_loader = create_phishpedia_loaders(
    phishing_dir=PHISHING_DIR,
    benign_dir=BENIGN_DIR,
    batch_size=BATCH_SIZE,
    max_samples=NUM_SAMPLES,
    image_size=(224, 224),
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY
)

print(f"\n Data loaders created:")
print(f"  Train: {len(train_loader.dataset):,}")
print(f"  Val: {len(val_loader.dataset):,}")
print(f"  Test: {len(test_loader.dataset):,}")
# Out:
# GPU SETUP AND DATASET LOADING
# GPU Available: Tesla T4
#    GPU Memory: 14.74 GB
#    CUDA Version: 12.6
#    Mixed Precision Training: Enabled
#
# Using device: cuda
#
# Configuration:
#   Batch size: 16
#   Num workers: 0
#   Pin memory: True
#   Num Samples: 2000
# === PHISHPEDIA DATASET ANALYSIS ===
#
# Total samples: 60,145
#   Phishing: 29,496
#   Benign: 30,649
#   Balance ratio: 1.04
#   Perfectly balanced
# Loaded 2000 all samples
#   Phishing: 1000
#   Benign: 1000
# Loaded 2000 all samples
#   Phishing: 1000
#   Benign: 1000
#
# Data splits:
#   Train: 1600 (80.0%)
#   Val: 200 (10.0%)
#   Test: 200 (10.0%)
#   DataLoader: num_workers=0, pin_memory=True
#
#  Data loaders created:
#   Train: 1,600
#   Val: 200
#   Test: 200

# %%
# Visualize Sample Data
sample_batch = next(iter(train_loader))

print(f"\nSample batch:")
print(f"  Images: {sample_batch['image'].shape}")
print(f"  Text IDs: {sample_batch['text_input_ids'].shape}")
print(f"  Labels: {sample_batch['label'].shape}")

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i in range(min(8, sample_batch['image'].shape[0])):
    img = sample_batch['image'][i]
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    img_denorm = torch.clamp((img * std + mean), 0, 1)

    axes[i].imshow(img_denorm.permute(1, 2, 0).numpy())
    label = "Phishing" if sample_batch['label'][i].item() == 1 else "Benign"
    axes[i].set_title(f"Label: {label}", fontsize=10)
    axes[i].axis('off')

plt.suptitle("Sample Images from Phishpedia Dataset", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Sample batch:
#   Images: torch.Size([16, 3, 224, 224])
#   Text IDs: torch.Size([16, 512])
#   Labels: torch.Size([16])

# %%
# Class Distribution Analysis and Visualization
print("CLASS DISTRIBUTION ANALYSIS")

# Calculate class distribution
class_counts = {0: 0, 1: 0}
# Use full dataset for accurate distribution if max_samples is used
if 'full_dataset' in locals():
    for sample in full_dataset:
        class_counts[int(sample['label'])] += 1
else: # Fallback to train loader if full_dataset not available (less accurate if max_samples is used)
     for batch in train_loader:
        for label in batch['label'].numpy():
            class_counts[int(label)] += 1


total_samples_dist = sum(class_counts.values())
if total_samples_dist > 0:
    benign_percentage = (class_counts.get(0, 0) / total_samples_dist) * 100
    phishing_percentage = (class_counts.get(1, 0) / total_samples_dist) * 100
else:
    benign_percentage = 0
    phishing_percentage = 0

print(f"\nClass distribution:")
print(f"  Benign: {class_counts.get(0, 0):,} ({benign_percentage:.2f}%)")
print(f"  Phishing: {class_counts.get(1, 0):,} ({phishing_percentage:.2f}%)")

# Visualize class distribution
if total_samples_dist > 0:
    labels = ['Benign', 'Phishing']
    counts = [class_counts.get(0, 0), class_counts.get(1, 0)]

    plt.figure(figsize=(6, 5))
    bars = plt.bar(labels, counts, color=['skyblue', 'salmon'])
    plt.ylabel('Number of Samples', fontsize=12)
    plt.title('Dataset Class Distribution', fontsize=14, fontweight='bold')
    plt.ylim(0, max(counts) * 1.1) # Add a little space above the tallest bar
    plt.grid(axis='y', alpha=0.3)

    # Add value labels on top of bars
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., yval + 0.05*max(counts), f'{yval:,}', ha='center', va='bottom', fontsize=10)


    plt.tight_layout()
    plt.show()
else:
    print("  No samples to visualize class distribution.")
# Out:
# CLASS DISTRIBUTION ANALYSIS
#
# Class distribution:
#   Benign: 806 (50.38%)
#   Phishing: 794 (49.62%)

# %%
# Model Initialization
print("MODEL INITIALIZATION")
# Device should already be set from Cell 16, but ensure it's correct
if 'device' not in locals():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"Device: {device}")
if torch.cuda.is_available():
    print(f"GPU Memory allocated: {torch.cuda.memory_allocated(0) / (1024**3):.2f} GB")
    print(f"GPU Memory reserved: {torch.cuda.memory_reserved(0) / (1024**3):.2f} GB")
print()

model = HybridPhishingDetector(
    visual_backbone="mobilenet_v2",
    visual_pretrained=True,
    visual_feature_dim=512,
    text_model_name="xlm-roberta-base",
    text_feature_dim=512,
    fusion_type="attention",
    num_classes=2,
    device=str(device)
).to(device)

total_params = sum(p.numel() for p in model.parameters())
model_size_mb = total_params * 4 / (1024 * 1024)

print(f"Model:")
print(f"  Parameters: {total_params:,}")
print(f"  Size: {model_size_mb:.2f} MB")
print(f"  Initialized on {device}")
# Out:
# MODEL INITIALIZATION
# Device: cuda
# GPU Memory allocated: 0.00 GB
# GPU Memory reserved: 0.00 GB
#
# Model:
#   Parameters: 284,637,058
#   Size: 1085.80 MB
#   Initialized on cuda

# %%
# Training Configuration
print("TRAINING CONFIGURATION")

class_weights = torch.tensor([
    1.0 / class_counts.get(0, 1),
    1.0 / class_counts.get(1, 1)
], dtype=torch.float32)
class_weights = class_weights / class_weights.sum() * 2

print(f"Class weights: {class_weights.tolist()}")

# Adapt batch format
def adapt_batch(batch):
    return {
        'images': batch['image'],
        'input_ids': batch['text_input_ids'],
        'attention_mask': batch['text_attention_mask'],
        'labels': batch['label']
    }

class AdaptedLoader:
    def __init__(self, loader):
        self.original_loader = loader
        self.dataset = loader.dataset

    def __iter__(self):
        for batch in self.original_loader:
            yield adapt_batch(batch)

    def __len__(self):
        return len(self.original_loader)

train_loader_adapted = AdaptedLoader(train_loader)
val_loader_adapted = AdaptedLoader(val_loader)


trainer = ModelTrainer(
    model=model,
    train_loader=train_loader_adapted,
    val_loader=val_loader_adapted,
    device=str(device),
    learning_rate=1e-4,
    loss_type="focal",
    class_weights=class_weights,
    focal_alpha=0.25,
    focal_gamma=4.0,
    use_amp=use_amp,
    early_stopping_patience=3 # Enable Early Stopping
)

print("Trainer initialized")
# Out:
# TRAINING CONFIGURATION
# Class weights: [0.9925000071525574, 1.0074999332427979]
# Mixed Precision Training (AMP) enabled for faster training
# Trainer initialized

# %%
# Model Training
print("MODEL TRAINING")

NUM_EPOCHS = 10

start_time = time.time()
train_history = trainer.train(num_epochs=NUM_EPOCHS)
training_time = time.time() - start_time

print(f"\nTraining completed in {training_time/60:.2f} minutes")
print(f"Final train loss: {train_history['train_losses'][-1]:.4f}")
print(f"Final val loss: {train_history['val_losses'][-1]:.4f}")
# Out:
# MODEL TRAINING
# Starting training with Early Stopping (patience=3)
#   Saved best model (Val Loss: 0.0111)
#
# Epoch 1/10:
#   Train Loss: 0.0160, Train Acc: 0.6725
#   Val Loss: 0.0111, Val Acc: 0.8050, Val F1: 0.7746
#   Saved best model (Val Loss: 0.0082)
#
# Epoch 2/10:
#   Train Loss: 0.0104, Train Acc: 0.8363
#   Val Loss: 0.0082, Val Acc: 0.8800, Val F1: 0.8667
#   No improvement (Counter: 1/3)
#
# Epoch 3/10:
#   Train Loss: 0.0081, Train Acc: 0.8912
#   Val Loss: 0.0089, Val Acc: 0.9100, Val F1: 0.9091
#   No improvement (Counter: 2/3)
#
# Epoch 4/10:
#   Train Loss: 0.0063, Train Acc: 0.9175
#   Val Loss: 0.0095, Val Acc: 0.9350, Val F1: 0.9326
#   No improvement (Counter: 3/3)
#
# Epoch 5/10:
#   Train Loss: 0.0056, Train Acc: 0.9350
#   Val Loss: 0.0097, Val Acc: 0.9050, Val F1: 0.9005
# Early stopping triggered at epoch 5
# Restored best model
#
# Training completed in 20.38 minutes
# Final train loss: 0.0056
# Final val loss: 0.0097

# %%
# Training Curves Visualization
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(train_history['train_losses'], label='Train Loss', linewidth=2)
axes[0].plot(train_history['val_losses'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(alpha=0.3)

if train_history.get('val_accuracies'):
    axes[1].plot(train_history['val_accuracies'], label='Val Accuracy', linewidth=2, color='green')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Validation Accuracy', fontsize=14, fontweight='bold')
    axes[1].legend()
    axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Comprehensive Evaluation
print("COMPREHENSIVE EVALUATION")
evaluator = ComprehensiveEvaluator()

all_preds, all_labels, all_probs = [], [], []

model.eval()
print("Collecting predictions...")
# Use mixed precision for faster inference on GPU
use_amp_inference = torch.cuda.is_available() and use_amp
autocast_context = torch.cuda.amp.autocast() if use_amp_inference else nullcontext()

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        images = batch['image'].to(device, non_blocking=True)
        text_input_ids = batch['text_input_ids'].to(device, non_blocking=True)
        text_attention_mask = batch['text_attention_mask'].to(device, non_blocking=True)
        labels = batch['label'].to(device, non_blocking=True)

        if use_amp_inference:
            with autocast_context:
                outputs = model(images, text_input_ids, text_attention_mask)
        else:
            outputs = model(images, text_input_ids, text_attention_mask)

        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs[:, 1].cpu().numpy())

eval_results = evaluator.evaluate_model(all_labels, all_preds, all_probs)
evaluator.generate_detailed_report(eval_results)
# Out:
# COMPREHENSIVE EVALUATION
# Collecting predictions...
# Evaluating: 100%|██████████| 13/13 [00:16<00:00,  1.27s/it]
# COMPREHENSIVE MODEL EVALUATION REPORT
# =====================================
#
# OVERALL PERFORMANCE:
# - Accuracy: 0.8500
# - Macro F1: 0.8498
# - Weighted F1: 0.8493
# - ROC-AUC: 0.9636
# - MCC: 0.7244
#
# PER-CLASS PERFORMANCE:
# Legitimate Class:
# - Precision: 0.7672
# - Recall: 0.9674
# - F1-Score: 0.8558
#
# Phishing Class:
# - Precision: 0.9643
# - Recall: 0.7500
# - F1-Score: 0.8438
#
# CRITICAL PHISHING DETECTION METRICS:
# - False Positive Rate: 0.0326
# - True Positive Rate (Sensitivity): 0.7500
# - Specificity: 0.9674
#
# CONFUSION MATRIX:
# [[89  3]
#  [27 81]]

# %%
# Calculate Confidence Intervals
ci_lower, ci_upper = calculate_confidence_intervals(all_labels, all_preds)
print(f"Accuracy 95% CI: {accuracy_score(all_labels, all_preds):.4f} ({ci_lower:.4f} - {ci_upper:.4f})")

eval_results = evaluator.evaluate_model(all_labels, all_preds, all_probs)
evaluator.generate_detailed_report(eval_results)

# Detailed Error Analysis
detailed_error_analysis(model, test_loader, device=device)
# Out:
# Accuracy 95% CI: 0.8500 (0.8005 - 0.8995)
#
# COMPREHENSIVE MODEL EVALUATION REPORT
# =====================================
#
# OVERALL PERFORMANCE:
# - Accuracy: 0.8500
# - Macro F1: 0.8498
# - Weighted F1: 0.8493
# - ROC-AUC: 0.9636
# - MCC: 0.7244
#
# PER-CLASS PERFORMANCE:
# Legitimate Class:
# - Precision: 0.7672
# - Recall: 0.9674
# - F1-Score: 0.8558
#
# Phishing Class:
# - Precision: 0.9643
# - Recall: 0.7500
# - F1-Score: 0.8438
#
# CRITICAL PHISHING DETECTION METRICS:
# - False Positive Rate: 0.0326
# - True Positive Rate (Sensitivity): 0.7500
# - Specificity: 0.9674
#
# CONFUSION MATRIX:
# [[89  3]
#  [27 81]]
# Error Analysis: 100%|██████████| 13/13 [00:19<00:00,  1.53s/it]
# === Error Analysis by Brand (Top 10) ===
# Brand: Unknown | Errors: 3 (FP: 3, FN: 0)
# Brand: Facebook, Inc. | Errors: 3 (FP: 0, FN: 3)
# Brand: PayPal Inc. | Errors: 2 (FP: 0, FN: 2)
# Brand: eBay Inc. | Errors: 2 (FP: 0, FN: 2)
# Brand: Deutsche Telekom | Errors: 1 (FP: 0, FN: 1)
# Brand: Steam | Errors: 1 (FP: 0, FN: 1)
# Brand: LinkedIn Corporation | Errors: 1 (FP: 0, FN: 1)
# Brand: Boxberry | Errors: 1 (FP: 0, FN: 1)
# Brand: NTT Communications | Errors: 1 (FP: 0, FN: 1)
# Brand: ICICI Bank Limited | Errors: 1 (FP: 0, FN: 1)
# {'Deutsche Telekom': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Unknown': {'fp': 3, 'fn': 0, 'total_errors': 3},
#  'Steam': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'LinkedIn Corporation': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Boxberry': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'NTT Communications': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'PayPal Inc.': {'fp': 0, 'fn': 2, 'total_errors': 2},
#  'Facebook, Inc.': {'fp': 0, 'fn': 3, 'total_errors': 3},
#  'ICICI Bank Limited': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'eBay Inc.': {'fp': 0, 'fn': 2, 'total_errors': 2},
#  'United Services Automobile Association': {'fp': 0,
#   'fn': 1,
#   'total_errors': 1},
#  'EMS': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Netflix Inc.': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'First Investment Bank': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Chase Personal Banking': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'DHL Airways, Inc.': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'DGI (French Tax Authority)': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Naver': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Stripe': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Dropbox, Inc.': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Yahoo! Inc': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'ATB Financial': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Lloyds TSB Group': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Alibaba': {'fp': 0, 'fn': 1, 'total_errors': 1},
#  'Orange': {'fp': 0, 'fn': 1, 'total_errors': 1}}

# %%
# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Benign', 'Phishing'],
            yticklabels=['Benign', 'Phishing'])
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

tn, fp, fn, tp = cm.ravel()
print(f"\nConfusion Matrix Details:")
print(f"  TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
print(f"  FPR: {fp/(fp+tn):.4f}, FNR: {fn/(fn+tp):.4f}")

# Cell 24: ROC and PR Curves
fpr, tpr, _ = roc_curve(all_labels, all_probs)
roc_auc = roc_auc_score(all_labels, all_probs)

precision, recall, _ = precision_recall_curve(all_labels, all_probs)
pr_auc = auc(recall, precision)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

axes[0].plot(fpr, tpr, linewidth=2, label=f'ROC (AUC = {roc_auc:.4f})')
axes[0].plot([0, 1], [0, 1], 'k--', linewidth=1)
axes[0].set_xlabel('False Positive Rate', fontsize=12)
axes[0].set_ylabel('True Positive Rate', fontsize=12)
axes[0].set_title('ROC Curve', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(alpha=0.3)

axes[1].plot(recall, precision, linewidth=2, label=f'PR (AUC = {pr_auc:.4f})')
axes[1].set_xlabel('Recall', fontsize=12)
axes[1].set_ylabel('Precision', fontsize=12)
axes[1].set_title('Precision-Recall Curve', fontsize=14, fontweight='bold')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nArea Under Curves:")
print(f"  ROC-AUC: {roc_auc:.4f}")
print(f"  PR-AUC: {pr_auc:.4f}")
# Out:
# Confusion Matrix Details:
#   TN: 89, FP: 3, FN: 27, TP: 81
#   FPR: 0.0326, FNR: 0.2500
# Area Under Curves:
#   ROC-AUC: 0.9636
#   PR-AUC: 0.9669

# %%
# Grad-CAM Setup and Generation
print("EXPLAINABILITY - GRAD-CAM")

try:
    target_layer = model.visual_branch.backbone.features[-1]
    visual_explainer = GradCAMExplainer(model, target_layer)
    print(" Grad-CAM explainer initialized")

    num_samples = min(8, len(test_loader.dataset))
    sample_images_list = []
    sample_heatmaps = []
    sample_labels_list = []
    sample_predictions_list = []

    model.eval()
    count = 0
    for batch in test_loader:
        if count >= num_samples:
            break
        images = batch['image'].to(device, non_blocking=True)
        text_input_ids = batch['text_input_ids'].to(device, non_blocking=True)
        text_attention_mask = batch['text_attention_mask'].to(device, non_blocking=True)
        labels = batch['label']

        for i in range(min(images.size(0), num_samples - count)):
            single_image = images[i:i+1].clone().detach().requires_grad_(True)
            single_text_ids = text_input_ids[i:i+1].to(device, non_blocking=True)
            single_text_mask = text_attention_mask[i:i+1].to(device, non_blocking=True)
            single_label = labels[i].item()

            try:
                # Generate heatmap with text inputs
                heatmap = visual_explainer.generate_heatmap(
                    single_image,
                    input_ids=single_text_ids,
                    attention_mask=single_text_mask
                )

                # Get prediction
                with torch.no_grad():
                    outputs = model(single_image.detach(), single_text_ids, single_text_mask)
                    pred = torch.argmax(outputs, dim=1).item()

                # Denormalize image for visualization
                mean = torch.tensor([0.485, 0.456, 0.406], device=device).view(1, 3, 1, 1)
                std = torch.tensor([0.229, 0.224, 0.225], device=device).view(1, 3, 1, 1)
                img_denorm = (single_image.detach() * std + mean).squeeze(0).cpu()

                # Ensure heatmap is 2D for visualization
                if len(heatmap.shape) > 2:
                    heatmap = np.mean(heatmap, axis=0) if heatmap.shape[0] > 1 else heatmap[0]
                elif len(heatmap.shape) == 1:
                    # If 1D, reshape to approximate square
                    side_len = int(np.sqrt(len(heatmap)))
                    heatmap = heatmap[:side_len*side_len].reshape(side_len, side_len)

                sample_images_list.append(img_denorm.permute(1, 2, 0).numpy())
                sample_heatmaps.append(heatmap)
                sample_labels_list.append(single_label)
                sample_predictions_list.append(pred)
                count += 1
            except Exception as e:
                print(f"  Warning: Sample {count} failed - {e}")
                continue

    # Only visualize if we have samples
    if len(sample_images_list) == 0:
        print("  No samples successfully processed for Grad-CAM visualization")
    else:
        # Visualize Grad-CAM
        fig, axes = plt.subplots(2, len(sample_images_list), figsize=(20, 6))
        if len(sample_images_list) == 1:
            axes = axes.reshape(2, 1)

        for i in range(len(sample_images_list)):
            img = sample_images_list[i]
            heatmap = sample_heatmaps[i]

            # Resize heatmap to match image dimensions
            if img.shape[0] > 0 and img.shape[1] > 0:
                heatmap_resized = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
                heatmap_uint8 = np.uint8(255 * heatmap_resized)
                heatmap_colored = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)
                heatmap_colored = cv2.cvtColor(heatmap_colored, cv2.COLOR_BGR2RGB)
                overlayed = cv2.addWeighted((img * 255).astype(np.uint8), 0.6, heatmap_colored, 0.4, 0) / 255.0

                axes[0, i].imshow(np.clip(img, 0, 1))
                label = "Phishing" if sample_labels_list[i] == 1 else "Benign"
                axes[0, i].set_title(f"True: {label}", fontsize=10)
                axes[0, i].axis('off')

                axes[1, i].imshow(np.clip(overlayed, 0, 1))
                pred = "Phishing" if sample_predictions_list[i] == 1 else "Benign"
                axes[1, i].set_title(f"Pred: {pred}\nGrad-CAM", fontsize=10)
                axes[1, i].axis('off')

        plt.suptitle('Grad-CAM Visualizations', fontsize=16, fontweight='bold')
        plt.tight_layout()
        plt.show()

        print(f" Generated Grad-CAM for {len(sample_heatmaps)} samples")

except Exception as e:
    print(f" Grad-CAM setup failed: {e}")
# Out:
# EXPLAINABILITY - GRAD-CAM
#  Grad-CAM explainer initialized
#  Generated Grad-CAM for 8 samples

# %%
# Error Analysis
print("ERROR ANALYSIS")

misclassified = []
correctly_classified = []

model.eval()
with torch.no_grad():
    for batch in test_loader:
        images = batch['image'].to(device)
        text_input_ids = batch['text_input_ids'].to(device)
        text_attention_mask = batch['text_attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(images, text_input_ids, text_attention_mask)
        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(outputs, dim=1)

        for i in range(len(labels)):
            label = labels[i].item()
            pred = preds[i].item()
            prob = probs[i, pred].item()

            if label != pred:
                misclassified.append({'true': label, 'pred': pred, 'conf': prob})
            else:
                correctly_classified.append({'true': label, 'pred': pred, 'conf': prob})

false_positives = sum(1 for m in misclassified if m['true'] == 0 and m['pred'] == 1)
false_negatives = sum(1 for m in misclassified if m['true'] == 1 and m['pred'] == 0)

total = len(misclassified) + len(correctly_classified)
error_rate = len(misclassified) / total if total > 0 else 0

print(f"Error Analysis:")
print(f"  Total samples: {total:,}")
print(f"  Correct: {len(correctly_classified):,}")
print(f"  Misclassified: {len(misclassified):,}")
print(f"  Error rate: {error_rate:.4f}")
print(f"  False Positives: {false_positives}")
print(f"  False Negatives: {false_negatives}")

# Visualize error distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].bar(['False Positives', 'False Negatives'], [false_positives, false_negatives],
            color=['orange', 'red'], alpha=0.7)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].set_title('Error Type Distribution', fontsize=14, fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)

if misclassified:
    misclass_conf = [m['conf'] for m in misclassified]
    correct_conf = [c['conf'] for c in correctly_classified[:len(misclassified)]]

    axes[1].hist(correct_conf, bins=20, alpha=0.6, label='Correct', color='green')
    axes[1].hist(misclass_conf, bins=20, alpha=0.6, label='Misclassified', color='red')
    axes[1].set_xlabel('Confidence', fontsize=12)
    axes[1].set_ylabel('Frequency', fontsize=12)
    axes[1].set_title('Confidence Distribution', fontsize=14, fontweight='bold')
    axes[1].legend()
    axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ERROR ANALYSIS
# Error Analysis:
#   Total samples: 200
#   Correct: 169
#   Misclassified: 31
#   Error rate: 0.1550
#   False Positives: 3
#   False Negatives: 28

# %%
# Adversarial Testing
print("ADVERSARIAL TESTING")

adversarial_tester = AdversarialTester(model, device=str(device))

num_adversarial_samples = min(100, len(test_loader.dataset))
test_images = []
test_input_ids = []
test_attention_mask = []
test_labels = []

count = 0
with torch.no_grad():
    for batch in test_loader:
        if count >= num_adversarial_samples:
            break
        for i in range(min(batch['image'].size(0), num_adversarial_samples - count)):
            test_images.append(batch['image'][i:i+1].to(device))
            test_input_ids.append(batch['text_input_ids'][i:i+1].to(device))
            test_attention_mask.append(batch['text_attention_mask'][i:i+1].to(device))
            test_labels.append(batch['label'][i:i+1].to(device))
            count += 1

epsilon_values = [0.01, 0.03, 0.05, 0.1]
robustness_results = {}

for epsilon in epsilon_values:
    correct_original = 0
    correct_adversarial = 0

    model.eval()
    for i in range(len(test_images)):
        with torch.no_grad():
            orig_output = model(test_images[i], test_input_ids[i], test_attention_mask[i])
            orig_pred = torch.argmax(orig_output, dim=1).item()

        if orig_pred == test_labels[i].item():
            correct_original += 1

        try:
            adv_image, _ = adversarial_tester.fgsm_attack(
                test_images[i], test_input_ids[i], test_attention_mask[i],
                test_labels[i], epsilon=epsilon, target_modality="visual"
            )

            with torch.no_grad():
                adv_output = model(adv_image, test_input_ids[i], test_attention_mask[i])
                adv_pred = torch.argmax(adv_output, dim=1).item()

            if adv_pred == test_labels[i].item():
                correct_adversarial += 1
        except:
            pass

    orig_acc = correct_original / len(test_images)
    adv_acc = correct_adversarial / len(test_images)
    robustness = adv_acc / orig_acc if orig_acc > 0 else 0

    robustness_results[epsilon] = {
        'original_accuracy': orig_acc,
        'adversarial_accuracy': adv_acc,
        'robustness_ratio': robustness
    }

print("\nAdversarial Robustness Results:")
print(f"{'Epsilon':<10} {'Original Acc':<15} {'Adversarial Acc':<18} {'Robustness':<12}")
print("-" * 60)
for eps, results in robustness_results.items():
    print(f"{eps:<10.3f} {results['original_accuracy']:<15.4f} "
          f"{results['adversarial_accuracy']:<18.4f} {results['robustness_ratio']:<12.4f}")

# Visualize robustness
epsilons = list(robustness_results.keys())
orig_accs = [robustness_results[eps]['original_accuracy'] for eps in epsilons]
adv_accs = [robustness_results[eps]['adversarial_accuracy'] for eps in epsilons]

plt.figure(figsize=(10, 6))
plt.plot(epsilons, orig_accs, 'o-', label='Original Accuracy', linewidth=2, markersize=8)
plt.plot(epsilons, adv_accs, 's-', label='Adversarial Accuracy', linewidth=2, markersize=8)
plt.xlabel('Epsilon (Perturbation Magnitude)', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Model Robustness Against FGSM Attacks', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ADVERSARIAL TESTING
#
# Adversarial Robustness Results:
# Epsilon    Original Acc    Adversarial Acc    Robustness
# ------------------------------------------------------------
# 0.010      0.8900          0.6400             0.7191
# 0.030      0.8900          0.6200             0.6966
# 0.050      0.8900          0.6100             0.6854
# 0.100      0.8900          0.5600             0.6292

# %%
#  Final Summary Report
print("FINAL SUMMARY REPORT")

summary = {
    'Dataset': {
        'Total samples': f"{NUM_SAMPLES:,}",
        'Training samples': f"{len(train_loader.dataset):,}",
        'Test samples': f"{len(test_loader.dataset):,}",
        'Class balance': f"{dataset_stats['balance_ratio']:.4f}"
    },
    'Model': {
        'Architecture': 'MobileNetV2 + XLM-RoBERTa',
        'Total parameters': f"{total_params:,}",
        'Model size': f"{model_size_mb:.2f} MB"
    },
    'Training': {
        'Epochs': NUM_EPOCHS,
        'Training time': f"{training_time/60:.2f} minutes",
        'Final train loss': f"{train_history['train_losses'][-1]:.4f}",
        'Final val loss': f"{train_history['val_losses'][-1]:.4f}"
    },
    'Performance': {
        'Accuracy': f"{eval_results['accuracy']:.4f}",
        'F1 Score': f"{eval_results['f1_weighted']:.4f}",
        'ROC-AUC': f"{eval_results.get('roc_auc', 'N/A')}",
        'MCC': f"{eval_results['mcc']:.4f}",
        'Inference time': f"{avg_inference_time:.2f} ms"
    },
    'Error Analysis': {
        'Error rate': f"{error_rate:.4f}",
        'False positives': false_positives,
        'False negatives': false_negatives
    }
}

for section, metrics in summary.items():
    print(f"\n{section}:")
    print("-" * 80)
    for key, value in metrics.items():
        print(f"  {key:<25}: {value}")
# Out:
# FINAL SUMMARY REPORT
#
# Dataset:
# --------------------------------------------------------------------------------
#   Total samples            : 2,000
#   Training samples         : 1,600
#   Test samples             : 200
#   Class balance            : 1.0391
#
# Model:
# --------------------------------------------------------------------------------
#   Architecture             : MobileNetV2 + XLM-RoBERTa
#   Total parameters         : 284,637,058
#   Model size               : 1085.80 MB
#
# Training:
# --------------------------------------------------------------------------------
#   Epochs                   : 10
#   Training time            : 20.38 minutes
#   Final train loss         : 0.0056
#   Final val loss           : 0.0097
#
# Performance:
# --------------------------------------------------------------------------------
#   Accuracy                 : 0.8500
#   F1 Score                 : 0.8493
#   ROC-AUC                  : 0.9635668276972624
#   MCC                      : 0.7244
#   Inference time           : 0.00 ms
#
# Error Analysis:
# --------------------------------------------------------------------------------
#   Error rate               : 0.1550
#   False positives          : 3
#   False negatives          : 28
